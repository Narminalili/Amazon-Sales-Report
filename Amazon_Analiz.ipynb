# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading and Initial Inspection

# %%
df = pd.read_csv(r"C:\Users\Narmin Alili\Desktop\Sale Report\Amazon-Sales-Report\Amazon Sale Report.csv", low_memory=False)
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# # Show first 5 rows

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %% [markdown]
# # Show the last 5 rows

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %% [markdown]
# # How many columns and rows are there in the dataset?

# %%
print(f"Dataset Dimensions: {df.shape}")
# Out:
# Dataset Dimensions: (128975, 24)

# %% [markdown]
# # Show statistical information of numeric columns

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %% [markdown]
# # Show column names

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='str')

# %% [markdown]
# # Dimensionality Reduction: Pruning Irrelevant Features

# %%
df.drop(['Unnamed: 22', 'fulfilled-by','ship-country', 'index'], axis=1, inplace=True)
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'promotion-ids', 'B2B'],
#       dtype='str')

# %% [markdown]
# # How many null values are there in total in each column?

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# promotion-ids         49153
# B2B                       0
# dtype: int64

# %% [markdown]
# # Records with missing Amount values were removed to maintain financial data integrity and ensure analysis accuracy.

# %%
df.dropna(subset=['Amount'], inplace=True)

# %% [markdown]
# # Remaining missing values in categorical columns were standardized to ensure dataset completeness.

# %%
df['promotion-ids'] = df['promotion-ids'].fillna('No Promotion')
df['Courier Status'] = df['Courier Status'].fillna('Unknown')

# %% [markdown]
# # Missing values in location-based columns were handled to ensure consistency across the dataset.

# %%
for col in ['ship-city', 'ship-state', 'ship-postal-code']:
    df[col] = df[col].fillna('Unknown')

# %% [markdown]
# # A final check was performed to ensure that all missing values were successfully addressed.

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# promotion-ids         0
# B2B                   0
# dtype: int64

# %% [markdown]
# # Data Types Verification

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 121180 entries, 0 to 121179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            121180 non-null  str
#  1   Date                121180 non-null  datetime64[us]
#  2   Status              121180 non-null  str
#  3   Fulfilment          121180 non-null  str
#  4   Sales Channel       121180 non-null  str
#  5   ship-service-level  121180 non-null  str
#  6   Style               121180 non-null  str
#  7   SKU                 121180 non-null  str
#  8   Category            121180 non-null  str
#  9   Size                121180 non-null  str
#  10  ASIN                121180 non-null  str
#  11  Courier Status      121180 non-null  str
#  12  Qty                 121180 non-null  int64
#  13  currency            121180 non-null  str
#  14  Amount              121180 non-null  float64
#  15  ship-city           121180 non-null  str
# ...

# %% [markdown]
# # The `Date` column was converted to a standardized datetime format to enable time-series analysis.

# %%
df['Date'] = pd.to_datetime(df['Date'], format='mixed', dayfirst=False, errors='coerce')

# %% [markdown]
# # To ensure consistent formatting and prevent mathematical errors, the `postal code` field was standardized as a string.

# %%
df['ship-postal-code'] = pd.to_numeric(df['ship-postal-code'], errors='coerce').fillna(0).astype(int)

# %%
df.to_csv('Amazon_Sale_Report_Cleaned.csv', index=False)

# %% [markdown]
# # Data Ingestion: Cleaned Dataset Loading
# # The final preprocessed and cleaned version of the dataset was imported into the environment for analysis.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 121180 entries, 0 to 121179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            121180 non-null  str
#  1   Date                121180 non-null  datetime64[us]
#  2   Status              121180 non-null  str
#  3   Fulfilment          121180 non-null  str
#  4   Sales Channel       121180 non-null  str
#  5   ship-service-level  121180 non-null  str
#  6   Style               121180 non-null  str
#  7   SKU                 121180 non-null  str
#  8   Category            121180 non-null  str
#  9   Size                121180 non-null  str
#  10  ASIN                121180 non-null  str
#  11  Courier Status      121180 non-null  str
#  12  Qty                 121180 non-null  int64
#  13  currency            121180 non-null  str
#  14  Amount              121180 non-null  float64
#  15  ship-city           121180 non-null  str
# ...

# %%
df = pd.read_csv(r"C:\Users\Narmin Alili\Desktop\Sale Report\Amazon_Sale_Report_Cleaned.csv", low_memory=False)
df
# Out:
#                    Order ID        Date                        Status  \
# 0       405-8078784-5731545  2022-04-30                     Cancelled
# 1       171-9198151-1101146  2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  2022-04-30                       Shipped
# 3       403-9615377-8133951  2022-04-30                     Cancelled
# 4       407-1069790-7240320  2022-04-30                       Shipped
# ...                     ...         ...                           ...
# 121175  406-6001380-7673107  2022-05-31                       Shipped
# 121176  402-9551604-7544318  2022-05-31                       Shipped
# 121177  407-9547469-3152358  2022-05-31                       Shipped
# 121178  402-6184140-0545956  2022-05-31                       Shipped
# 121179  408-7436540-8728312  2022-05-31                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %% [markdown]
# # How has the total revenue evolved over the specified time period?

# %%
daily_revenue = df.groupby('Date')['Amount'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_revenue, x='Date', y='Amount', color='darkblue', linewidth=2, marker='o')
plt.title('Total Revenue Evolution Over Time', fontsize=15, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Revenue (INR)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the distribution of product categories in the orders?

# %%
category_sales = df.groupby('Category')['Amount'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=category_sales.index, y=category_sales.values, hue=category_sales.index, palette='magma', legend=False)

plt.title('Revenue by Category', fontsize=15)
plt.xlabel('Product Category')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # What is the typical quantity of products per order?

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x='Qty', hue='Qty', palette='coolwarm', legend=False)

plt.title('Distribution of Product Quantity per Order', fontsize=15, fontweight='bold')
plt.xlabel('Quantity per Order', fontsize=12)
plt.ylabel('Order Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
print("Quantity Statistics:")
print(df['Qty'].describe())
# Out:
# Quantity Statistics:
# count    121180.000000
# mean          0.961231
# std           0.214354
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           8.000000
# Name: Qty, dtype: float64

# %% [markdown]
# # What are the top geographical markets based on order volume?

# %%
top_states = df['ship-state'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_states.values, y=top_states.index, hue=top_states.index, palette='coolwarm', legend=False)

plt.title('Top 10 States by Order Volume', fontsize=15)
plt.xlabel('Number of Orders')
plt.ylabel('State')
plt.show()

# %% [markdown]
# # How are sales distributed between B2B and individual consumers?

# %%
b2b_counts = df['B2B'].value_counts()

plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='B2B', hue='B2B', palette='Set1', legend=False)

plt.title('Sales Distribution: B2B vs. Individual Consumers', fontsize=14, fontweight='bold')
plt.xlabel('Is B2B?', fontsize=12)
plt.ylabel('Number of Orders', fontsize=12)
plt.xticks([0, 1], ['Consumer (False)', 'B2B (True)']) # Oxun adlarını daha anlaşıqlı edək

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the ratio of successful deliveries compared to cancellations and returns?

# %%
status_counts = df['Status'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=status_counts.values, y=status_counts.index, hue=status_counts.index, palette='viridis', legend=False)

plt.title('Distribution of Order Status', fontsize=14)
plt.xlabel('Number of Orders')
plt.ylabel('Status')
plt.show()

# %% [markdown]
# # What are the most preferred product sizes among the customer base?

# %%
size_counts = df['Size'].value_counts()

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Size', order=size_counts.index, hue='Size', palette='Blues_r', legend=False)

plt.title('Customer Preference by Product Size', fontsize=14)
plt.xlabel('Size')
plt.ylabel('Order Count')
plt.show()

# %% [markdown]
# # How effective is the transition from courier handling to final delivery?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Courier Status', hue='Status', palette='Set2')
plt.title('Courier Status vs. Final Order Status', fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # What is the distribution between Amazon-fulfilled and Merchant-fulfilled logistics?

# %%
fulfillment_counts = df['Fulfilment'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(fulfillment_counts, labels=fulfillment_counts.index, autopct='%1.1f%%', 
        colors=['#ff9999','#66b3ff'], startangle=140, explode=(0.05, 0))
plt.title('Distribution of Fulfilment Methods', fontsize=14)
plt.show()

# %%
b2b_data = df['B2B'].value_counts()

colors = ['#1f77b4', '#ff7f0e'] 
labels = ['Individual Consumer', 'B2B']
explode = (0, 0.2) 

plt.figure(figsize=(10, 7))
plt.pie(b2b_data, labels=labels, autopct='%1.1f%%', 
        startangle=140, colors=colors, explode=explode, shadow=True)

plt.title('Customer Segment Distribution (B2C vs. B2B)', fontsize=15, fontweight='bold')
plt.show()

print(f"Total Transactions: {len(df)}")
print(f"Individual Orders: {b2b_data[False]}")
print(f"B2B Orders: {b2b_data[True]}")
# Out:
# Total Transactions: 121180
# Individual Orders: 120337
# B2B Orders: 843

# %% [markdown]
# # Create a heatmap to visualize the distribution of sales across months and days of the week based on the dataset.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month_name()
df['Weekday'] = df['Date'].dt.day_name()

days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
months_order = df['Month'].unique()

heatmap_data = df.pivot_table(index='Month', columns='Weekday', values='Amount', aggfunc='sum')
heatmap_data = heatmap_data[days_order] 

plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu", linewidths=.5)

plt.title('Sales Heatmap: Months vs. Weekdays', fontsize=15, fontweight='bold')
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Month', fontsize=12)

plt.show()
